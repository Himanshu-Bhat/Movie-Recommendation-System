# %% [markdown]
# ### **Movie Recommendation System**

# %% [markdown]
# #### **Fetching Data using TMDB API**

# %%
import pandas as pd
import requests

api_key = '*************'
url_link = f'https://api.themoviedb.org/3/movie/top_rated?api_key={api_key}&language=en-US&page='

df = pd.DataFrame()
total_pages = 471
for page_num in range(1,total_pages):
    req = requests.get(url=f'{url_link}{page_num}')
    temp_df = pd.DataFrame(req.json()['results'],columns=['original_title','overview','genre_ids','original_language','vote_average','release_date','id'])
    df = df.append([temp_df],ignore_index=True)

df.head()
# Out:
#                  original_title  \
# 0      The Shawshank Redemption
# 1  दिलवाले दुल्हनिया ले जायेंगे
# 2                 The Godfather
# 3              Cosas imposibles
# 4              Schindler's List
#
#                                             overview        genre_ids  \
# 0  Framed in the 1940s for the double murder of h...         [18, 80]
# 1  Raj is a rich, carefree, happy-go-lucky second...  [35, 18, 10749]
# 2  Spanning the years 1945 to 1955, a chronicle o...         [18, 80]
# 3  A widow who is tormented by the memory of her ...      [10751, 18]
# 4  The true story of how businessman Oskar Schind...  [18, 36, 10752]
#
#   original_language  vote_average release_date      id
# 0                en           8.7   1994-09-23     278
# 1                hi           8.7   1995-10-20   19404
# 2                en           8.7   1972-03-14     238
# 3                es           8.7   2021-06-17  667257
# 4                en           8.6   1993-11-30     424

# %%
# General Info about Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9400 entries, 0 to 9399
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   original_title     9400 non-null   object
#  1   overview           9400 non-null   object
#  2   genre_ids          9400 non-null   object
#  3   original_language  9400 non-null   object
#  4   vote_average       9400 non-null   float64
#  5   release_date       9400 non-null   object
#  6   id                 9400 non-null   int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 514.2+ KB

# %% [markdown]
# from above we can see that dataset has 0 missing values.

# %%
# converting Genre_Ids into Genres
genre_dict = { 28:'Action', 
               12:'Adventure', 
               16:'Animation',
               35:'Comedy',
               80:'Crime',
               99:'Documentary',
               18:'Drama',
               10751:'Family',
               14:'Fantasy',
               36:'History',
               27:'Horror',
               10402:'Music',
               9648:'Mystery',
               10749:'Romance',
               878:'Science Fiction',
               10770:'TV Movie',
               53:'Thriller',
               10752:'War',
               37:'Western'
             }
def genre_detector(genre_ids):
    genre_list = []
    for genre_id in genre_ids:
        genre_list.append(genre_dict[genre_id])
    return ' , '.join(genre_list)

df['genre'] = df['genre_ids'].apply(genre_detector)
df.drop(columns=['genre_ids'],inplace=True)

df.head(3)
# Out:
#                  original_title  \
# 0      The Shawshank Redemption
# 1  दिलवाले दुल्हनिया ले जायेंगे
# 2                 The Godfather
#
#                                             overview original_language  \
# 0  Framed in the 1940s for the double murder of h...                en
# 1  Raj is a rich, carefree, happy-go-lucky second...                hi
# 2  Spanning the years 1945 to 1955, a chronicle o...                en
#
#    vote_average release_date     id                     genre
# 0           8.7   1994-09-23    278             Drama , Crime
# 1           8.7   1995-10-20  19404  Comedy , Drama , Romance
# 2           8.7   1972-03-14    238             Drama , Crime

# %%
# Taking Year out of release_date
df['release_year'] = df['release_date'].str[:4]
df.drop(columns=['release_date'],inplace=True)
df.head(3)
# Out:
#                  original_title  \
# 0      The Shawshank Redemption
# 1  दिलवाले दुल्हनिया ले जायेंगे
# 2                 The Godfather
#
#                                             overview original_language  \
# 0  Framed in the 1940s for the double murder of h...                en
# 1  Raj is a rich, carefree, happy-go-lucky second...                hi
# 2  Spanning the years 1945 to 1955, a chronicle o...                en
#
#    vote_average     id                     genre release_year
# 0           8.7    278             Drama , Crime         1994
# 1           8.7  19404  Comedy , Drama , Romance         1995
# 2           8.7    238             Drama , Crime         1972

# %%
# Converting all in Lowercase
df['overview'] = df['overview'].str.lower()

# %%
# Removing Punctuations 

import string
exclude = string.punctuation

def remove_punc(txt):
    return txt.translate(str.maketrans('', '', exclude))

df['overview'] = df['overview'].apply(remove_punc)
df.sample(3)
# Out:
#                 original_title  \
# 1804  Tucker and Dale vs. Evil
# 6355                        神話
# 2949      My Own Private Idaho
#
#                                                overview original_language  \
# 1804  two hillbillies are suspected of being killers...                en
# 6355  when a fellow scientist asks for jacks help in...                zh
# 2949  in this loose adaptation of shakespeares henry...                en
#
#       vote_average     id                                          genre  \
# 1804           7.4  46838                                Comedy , Horror
# 6355           6.3  11653  Action , Adventure , Comedy , Drama , Fantasy
# 2949           7.1    468                              Drama , Adventure
#
#      release_year
# 1804         2010
# 6355         2005
# 2949         1991

# %%
# Removing Stop words

from nltk.corpus import stopwords
stop_words = stopwords.words('english')

def remove_stops(txt):
    new_txt = []
    
    for word in txt.split():
        if word in stop_words:
            new_txt.append(' ')
        else:
            new_txt.append(word)
    x = new_txt[:]
    new_txt.clear()
    return ' '.join(x)

df['overview'] = df['overview'].apply(remove_stops)
df.head(3)
# Out:
#                  original_title  \
# 0      The Shawshank Redemption
# 1  दिलवाले दुल्हनिया ले जायेंगे
# 2                 The Godfather
#
#                                             overview original_language  \
# 0  framed     1940s     double murder     wife   ...                en
# 1  raj     rich carefree happygolucky second gene...                hi
# 2  spanning   years 1945   1955   chronicle     f...                en
#
#    vote_average     id                     genre release_year
# 0           8.7    278             Drama , Crime         1994
# 1           8.7  19404  Comedy , Drama , Romance         1995
# 2           8.7    238             Drama , Crime         1972

# %%
# Stemming : Process of retrieving root form out of word

from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

def stemmer(txt):
    return ' '.join([ps.stem(word) for word in txt.split()])

df['overview'] = df['overview'].apply(stemmer)
df.head(3)
# Out:
#                  original_title  \
# 0      The Shawshank Redemption
# 1  दिलवाले दुल्हनिया ले जायेंगे
# 2                 The Godfather
#
#                                             overview original_language  \
# 0  frame 1940 doubl murder wife lover upstand ban...                en
# 1  raj rich carefre happygolucki second gener nri...                hi
# 2  span year 1945 1955 chronicl fiction italianam...                en
#
#    vote_average     id                     genre release_year
# 0           8.7    278             Drama , Crime         1994
# 1           8.7  19404  Comedy , Drama , Romance         1995
# 2           8.7    238             Drama , Crime         1972

# %%
df['tags'] = df['original_title'] + ' ' + df['original_language'] + ' ' + df['release_year'] + ' ' + df['genre'] + ' ' + df['vote_average'].astype(str) + ' ' + df['overview']
df.drop(columns=['overview','original_language','vote_average','genre','release_year'],inplace=True)
df.head(3)
# Out:
#                  original_title     id  \
# 0      The Shawshank Redemption    278
# 1  दिलवाले दुल्हनिया ले जायेंगे  19404
# 2                 The Godfather    238
#
#                                                 tags
# 0  The Shawshank Redemption en 1994 Drama , Crime...
# 1  दिलवाले दुल्हनिया ले जायेंगे hi 1995 Comedy , ...
# 2  The Godfather en 1972 Drama , Crime 8.7 span y...

# %% [markdown]
# ##### **Bag Of Words**

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000)

vector1 = cv.fit_transform(df['tags']).toarray()

# %%
# to create array of distance/angle
from sklearn.metrics.pairwise import cosine_similarity
similarity1 = cosine_similarity(vector1)

# %%
def BoW_recommend(movie):
    movie_index = df[df['original_title'] == movie].index[0]
    movie_list  = sorted(list(enumerate(similarity1[movie_index])),reverse=True,key = lambda x: x[1])[1:6]
    for i in movie_list:
        print(df.iloc[i[0]].original_title)

# %%
BoW_recommend('Batman v Superman: Dawn of Justice')
# Out:
# Superman: Unbound
# Injustice
# Superman/Batman: Apocalypse
# Batman: Mystery of the Batwoman
# Superman/Batman: Public Enemies

# %% [markdown]
# ##### **TF-IDF**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features=5000)

vector2 = tfidf.fit_transform(df['tags']).toarray()

# %%
# to create array of distance/angle
from sklearn.metrics.pairwise import cosine_similarity
similarity2 = cosine_similarity(vector2)

# %%
def TF_IDF_recommend(movie):
    movie_index = df[df['original_title'] == movie].index[0]
    movie_list  = sorted(list(enumerate(similarity2[movie_index])),reverse=True,key = lambda x: x[1])[1:6]
    for i in movie_list:
        print(df.iloc[i[0]].original_title)

# %%
TF_IDF_recommend('Batman v Superman: Dawn of Justice')
# Out:
# Superman/Batman: Apocalypse
# Superman: Unbound
# Superman/Batman: Public Enemies
# Lego Batman: The Movie - DC Super Heroes Unite
# Injustice

# %% [markdown]
# TF-IDF is recommending better results...

# %%
# Dumping Movie list & TF-IDF Model
import pickle

pickle.dump(df,open('movie_list.pkl','wb'))
pickle.dump(similarity2,open('similarity.pkl','wb'))
